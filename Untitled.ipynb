# %%
from matplotlib import pyplot as plt
import math

x_ax = []
y_ax = []
bottom, top = plt.ylim()

for i in range(1, 101):
    x_ax.append(i)
    y_ax.append(math.sin(i))
    
plt.grid()
plt.plot(x_ax, y_ax)
plt.ylim(top=3)
plt.show()
